# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from FRED_data_pull import *
from pathlib import Path
from datetime import datetime, timedelta
import os
import dotenv
import math
dotenv.load_dotenv()
api_key = os.environ['FRED_API_KEY']
from dateutil.relativedelta import relativedelta
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
data_raw = pd.DataFrame()
data_quarterly = pd.DataFrame()

# %%
## Quarterly Figures
gdp = pull_data(['GDPC1'],
                 'q', api_key)
gdp_pce = pull_data(['PCECC96'],
                 'q', api_key)
gpdi = pull_data(['GPDIC1'],
                 'q', api_key)
gce = pull_data(['GCEC1'],
                 'q', api_key)
imports = pull_data(['IMPGSC1'],
                 'q', api_key)
exports = pull_data(['EXPGSC1'],
                 'q', api_key)
gdp_deflator = pull_data(['GDPDEF'],
                 'q', api_key)

data_quarterly['GDP'] = gdp
data_quarterly['GDP_PCE'] = gdp_pce
data_quarterly['GPDI'] = gpdi
data_quarterly['GCE'] = gce
data_quarterly['Imports'] = imports
data_quarterly['Exports'] = exports
data_quarterly['GDP_deflator'] = gdp_deflator
data_quarterly = data_quarterly[::-1]
# Out:
# C:\Users\alex.zhang\AppData\Local\anaconda3\envs\transports\lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.stlouisfed.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\alex.zhang\AppData\Local\anaconda3\envs\transports\lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.stlouisfed.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\alex.zhang\AppData\Local\anaconda3\envs\transports\lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.stlouisfed.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\alex.zhang\AppData\Local\anaconda3\envs\transports\lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.stlouisfed.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\alex.zhang\AppData\Local\anaconda3\envs\transports\lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.stlouisfed.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\alex.zhang\AppData\Local\anaconda3\envs\transports\lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.stlouisfed.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\alex.zhang\AppData\Local\anaconda3\envs\transports\lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.stlouisfed.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
## Inflation
crude = pull_data(['DCOILWTICO'],
                 'm', api_key)
ppi = pull_data(['PPIACO'],
                 'm', api_key)
cpi = pull_data(['CPIAUCSL'],
                 'm', api_key)
#core_cpi = pull_data(['CPILFESL'],
#                 'm', api_key)
pce_prices = pull_data(['PCEPI'],
                 'm', api_key)
#core_pce = pull_data(['PCEPILFE'],
#                 'm', api_key)
#gasoline = pull_data(['GASREGW'],
#                 'm', api_key)

data_raw['Crude_Oil'] = crude
data_raw['PPI'] = ppi
data_raw['CPI'] = cpi
data_raw['PCE_Prices'] = pce_prices
# Out:
# C:\Users\alex.zhang\AppData\Local\anaconda3\envs\transports\lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.stlouisfed.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\alex.zhang\AppData\Local\anaconda3\envs\transports\lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.stlouisfed.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\alex.zhang\AppData\Local\anaconda3\envs\transports\lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.stlouisfed.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\alex.zhang\AppData\Local\anaconda3\envs\transports\lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.stlouisfed.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
## Output and Income
ip = pull_data(['INDPRO'],
                 'm', api_key)
personal_income = pull_data(['PI'],
                 'm', api_key)
disposable_income = pull_data(['DSPI'],
                 'm', api_key)
capacity_utilization = pull_data(['TCU'],
                 'm', api_key)

data_raw['Industrial_Production'] = ip
data_raw['Personal_Income'] = personal_income
data_raw['Disposable_Income'] = disposable_income
data_raw['Capacity_Utilization'] = capacity_utilization
# Out:
# C:\Users\alex.zhang\AppData\Local\anaconda3\envs\transports\lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.stlouisfed.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\alex.zhang\AppData\Local\anaconda3\envs\transports\lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.stlouisfed.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\alex.zhang\AppData\Local\anaconda3\envs\transports\lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.stlouisfed.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\alex.zhang\AppData\Local\anaconda3\envs\transports\lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.stlouisfed.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
## Consumption, Orders, and Inventories
pce = pull_data(['PCE'],
                 'm', api_key)
retail_sales = pull_data(['RRSFS'],
                 'm', api_key)
new_orders = pull_data(['AMTMNO'],
                 'm', api_key)
michigan_sentiment = pull_data(['UMCSENT'],
                 'm', api_key)

pce = pce/pce_prices

data_raw['PCE'] = pce
data_raw['Retail_Sales'] = retail_sales
data_raw['New_Orders'] = new_orders
data_raw['Michigan_Sentiment'] = michigan_sentiment
# Out:
# C:\Users\alex.zhang\AppData\Local\anaconda3\envs\transports\lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.stlouisfed.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\alex.zhang\AppData\Local\anaconda3\envs\transports\lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.stlouisfed.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\alex.zhang\AppData\Local\anaconda3\envs\transports\lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.stlouisfed.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\alex.zhang\AppData\Local\anaconda3\envs\transports\lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.stlouisfed.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_744\1973950226.py in ?()
#       9                  'm', api_key)
#      10
#      11 pce = pce/pce_prices
#      12
# ---> 13 data_raw['PCE'] = pce
#      14 data_raw['Retail_Sales'] = retail_sales
#      15 data_raw['New_Orders'] = new_orders
#      16 data_raw['Michigan_Sentiment'] = michigan_sentiment
#
# ~\AppData\Local\anaconda3\envs\transports\lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    3936             self._setitem_frame(key, value)
#    3937         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    3938             self._setitem_array(key, value)
#    3939         elif isinstance(value, DataFrame):
# -> 3940             self._set_item_frame_value(key, value)
#    3941         elif (
#    3942             is_list_like(value)
#    3943             and not self.columns.is_unique
#
# ~\AppData\Local\anaconda3\envs\transports\lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4090             self._set_item_mgr(key, arraylike)
#    4091             return
#    4092
#    4093         if len(value.columns) != 1:
# -> 4094             raise ValueError(
#    4095                 "Cannot set a DataFrame with multiple columns to the single "
#    4096                 f"column {key}"
#    4097             )
#
# ValueError: Cannot set a DataFrame with multiple columns to the single column PCE

# %%
## Labor Market
unemployment = pull_data(['UNRATE'],
                 'm', api_key)
nfp = pull_data(['PAYEMS'],
                 'm', api_key)
#hours = pull_data(['AWHAETP'],
#                 'm', api_key)
initial_claims = pull_data(['ICSA'],
                 'm', api_key)
continued_claims = pull_data(['CCSA'],
                 'm', api_key)
#hourly_wage = pull_data(['CES0500000003'],
#                 'm', api_key)

data_raw['Unemployment'] = unemployment
data_raw['NFP'] = nfp
#data_raw['Weekly_Hours'] = hours
data_raw['Initial_Claims'] = initial_claims
data_raw['Initial_Claims'] = continued_claims
#data_raw['Hourly_Earnings'] = hourly_wage

# %%
## Housing
permits = pull_data(['PERMIT'],
                 'm', api_key)
housing_starts = pull_data(['HOUST'],
                 'm', api_key)

data_raw['Permits'] = permits
data_raw['Housing_Starts'] = housing_starts

# %%
## Financial Conditions
#dollar = pull_data(['DTWEXBGS'],
#                 'm', api_key)
mortage_rates = pull_data(['MORTGAGE30US'],
                 'm', api_key)
ten_year_yield = pull_data(['GS10'],
                 'm', api_key)
two_year_yield = pull_data(['GS2'],
                 'm', api_key)
fed_funds = pull_data(['EFFR'],
                 'm', api_key)
vix = pull_data(['VIXCLS'],
                 'm', api_key)
money_supply = pull_data(['M2REAL'],
                 'm', api_key)
stocks = pull_data(['SPASTT01USM661N'],
                 'm', api_key)

#data_raw['DXY'] = dollar
data_raw['Mortgage_Rates'] = mortage_rates
data_raw['10y_Yield'] = ten_year_yield
data_raw['2y_Yield'] = two_year_yield
data_raw['Fed_Funds'] = fed_funds
data_raw['VIX'] = vix
data_raw['Money_Supply'] = money_supply
data_raw['Stocks'] = stocks

# %%
#file_path = Path("ism_services_df.xlsx")
#ism_services_df = pd.read_excel(file_path).set_index('date')
#file_path = Path("ism_manufacturing_df.xlsx")
#ism_manufacturing_df = pd.read_excel(file_path).set_index('date')
file_path = Path("dxy_df.xlsx")
dxy_df = pd.read_excel(file_path).set_index('date')
#file_path = Path("philly_services_df.xlsx")
#philly_services_df = pd.read_excel(file_path).set_index('date')
#file_path = Path("philly_manufacturing_df.xlsx")
#philly_manufacturing_df = pd.read_excel(file_path).set_index('date')
#file_path = Path("empire_manufacturing_df.xlsx")
#empire_manufacturing_df = pd.read_excel(file_path).set_index('date')
#file_path = Path("nfib_prices_df.xlsx")
#nfib_prices_df = pd.read_excel(file_path).set_index('date')
#file_path = Path("Adobe DPI.xlsx")
#adbe_df = pd.read_excel(file_path).set_index('date')

# %%
#data_raw = pd.DataFrame()
#data_raw['DXY'] = dollar
#data_raw['Gasoline'] = gasoline
#data_raw['Crude'] = crude
#data_raw['Unemployment'] = unemployment
#data_raw['CPI'] = cpi
#data_raw['Core CPI'] = core_cpi
#data_raw['PCE'] = pce
#data_raw['Core PCE'] = core_pce
##data_raw['Import Prices'] = import_prices
#data_raw['Core Import Prices'] = core_import_prices
#data_raw['PPI'] = ppi
#data_raw['Core PPI'] = core_ppi
#data_raw['Expectations'] = inflation_expectations

data_raw['DXY'] = dxy_df

data_raw = data_raw[::-1]

# %%
data = (np.log(data_raw).diff()*100)[1:]
data['Unemployment'] = (data_raw['Unemployment'].diff()*100)[1:]
data['Mortgage_Rates'] = (data_raw['Mortgage_Rates'].diff()*100)[1:]
data['10y_Yield'] = (data_raw['10y_Yield'].diff()*100)[1:]
data['2y_Yield'] = (data_raw['2y_Yield'].diff()*100)[1:]
data['Fed_Funds'] = (data_raw['Fed_Funds'].diff()*100)[1:]
data['Capacity_Utilization'] = (data_raw['Capacity_Utilization'].diff()*100)[1:]
#data['EXPINF2YR'] = (data_raw['EXPINF2YR'].diff()*1200)[1:]
#data['Expectations'] = (data_raw['Expectations'].diff()*100)[1:]

#data.iloc[-2,3] = np.nan
#data.iloc[-2,4] = np.nan
#data.iloc[-2,5] = np.nan
#data.iloc[-2,6] = np.nan
#data.iloc[-2,7] = np.nan
#data.iloc[-2,8] = np.nan
#data.iloc[-2,9] = np.nan
data_quarterly = (np.log(data_quarterly).diff()*100)[1:]

# %%
#data['ISM Services'] = ism_services_df 
#data['ISM Manufacturing'] = ism_manufacturing_df 
#data['Empire Manufacturing'] = empire_manufacturing_df 
#data['Philly Services'] = philly_services_df 
#data['Philly Manufacturing'] = philly_manufacturing_df 
#data['NFIB Price Plans'] = nfib_prices_df
#data['Adobe DPI'] = adbe_df*1200
#data['Philly Empire Average'] = (philly_manufacturing_df['philly_index'] + empire_manufacturing_df['empire_index']) / 2

# %%
data = data[data.index >= '2003-04-30']
data_quarterly = data_quarterly[data_quarterly.index >= '2003-06-30']
#data = data[data.index >= '2011-03-31']
#data = data[data.index >= '2014-01-31']

# %%
## Seasonal Adjustment

# Decompose
#decomposition = sm.tsa.seasonal_decompose(data['Gasoline'], model='additive')

# Extract the components
#trend = decomposition.trend
#seasonal = decomposition.seasonal
#residual = decomposition.resid

# Seasonally adjust
#data['Gasoline'] = data['Gasoline'] - seasonal

# %%
# Decompose
#decomposition = sm.tsa.seasonal_decompose(data['Import Prices'], model='additive')

# Extract the components
#trend = decomposition.trend
#seasonal = decomposition.seasonal
#residual = decomposition.resid

# Seasonally adjust
#data['Import Prices'] = data['Import Prices'] - seasonal

# %%
data.corr()

# %%
data_norm = (data - data.mean()) / data.std()
var_name_1 = 'Crude_Oil'
var_name_2 = 'CPI'
plt.plot(data_norm.index, data_norm[var_name_1], label=var_name_1)
plt.plot(data_norm.index, data_norm[var_name_2], label=var_name_2)
plt.legend()
plt.show()

# %%
data

# %% [markdown]
# ## PCA (To Get K_Factor)

# %%
# Standardize the features (important for PCA)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(data.dropna())

n_components = 5  # Choose the number of components (dimensions) you want to reduce to
pca = PCA(n_components=n_components)
X_pca = pca.fit_transform(X_scaled)

# %%
explained_variance = pca.explained_variance_ratio_
print("Explained Variance Ratio:", explained_variance)
# Out:
# Explained Variance Ratio: [0.34526434 0.13451026 0.09165338 0.08269872 0.07108173]

# %% [markdown]
# # Fit Model

# %%
factors = {'GDP': ['Global', 'Demand'],
           'GPDI': ['Global', 'Demand'],
           'GCE': ['Global', 'Financial_Conditions'],
           'Crude_Oil': ['Global', 'Inflation'],
           'PPI' : ['Global', 'Inflation'],
           'CPI' : ['Global', 'Inflation'],
           'PCE_Prices' : ['Global', 'Inflation'],
           'GDP_deflator' : ['Global', 'Inflation'],
           'Personal_Income' : ['Global', 'Income'],
           'Disposable_Income' : ['Global', 'Income'],
           'GDP_PCE' : ['Global', 'Demand'],
           'Imports' : ['Global', 'Demand'],
           'Exports' : ['Global', 'Demand'],
           'PCE' : ['Global', 'Demand'],
           'Retail_Sales' : ['Global', 'Demand'],
           'Industrial_Production' : ['Global', 'Demand'],
           'Capacity_Utilization' : ['Global', 'Demand'],
           'New_Orders' : ['Global', 'Demand'],
           'Michigan_Sentiment' : ['Global'],
           'Unemployment' : ['Global', 'Labor Market'],
           'NFP' : ['Global', 'Labor Market'],
           'Weekly_Hours' : ['Global', 'Labor Market'],
           'Initial_Claims' : ['Global', 'Labor Market'],
           'Permits' : ['Global', 'Housing'],
           'Housing_Starts' : ['Global', 'Housing'],
           'VIX' : ['Global', 'Financial_Conditions'],
           'Mortgage_Rates' : ['Global', 'Financial_Conditions'],
           '10y_Yield' : ['Global', 'Financial_Conditions'],
           '2y_Yield' : ['Global', 'Financial_Conditions'],
           'Fed_Funds' : ['Global', 'Financial_Conditions'],
           'Stocks' : ['Global', 'Financial_Conditions'],
           'Money_Supply' : ['Global', 'Financial_Conditions'],
           'DXY' : ['Global','Financial_Conditions']}
factor_orders = {'Global': 3}
factor_multiplicities = {'Global': 3}

# %%
data.index.freq='M'
data_quarterly.index.freq='Q'

# %%
cutoff = 1
#const_pre = np.ones(len(data)-cutoff)
model = sm.tsa.DynamicFactorMQ(data[:-cutoff], endog_quarterly=data_quarterly, factors=factors, factor_orders=3, factor_multiplicities=factor_multiplicities, freq = 'M')#, enforce_stationarity=False)

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                          Model Specification: Dynamic Factor Model
# ===========================================================================================
# Model:                Dynamic Factor Model   # of monthly variables:                     25
#                    + 9 factors in 7 blocks   # of quarterly variables:                    7
#                    + Mixed frequency (M/Q)   # of factor blocks:                          7
#                      + AR(1) idiosyncratic   Idiosyncratic disturbances:              AR(1)
# Sample:                            2003-04   Standardize variables:                    True
#                                  - 2024-03
#                                                  Observed variables / factor loadings
# =====================================================================================================================================
#         Dep. variable   Global.1   Global.2   Global.3      Demand Financial_Conditions  Inflation Labor Market    Housing     Income
# -------------------------------------------------------------------------------------------------------------------------------------
#             Crude_Oil      X          X          X                                           X
#                   PPI      X          X          X                                           X
#                   CPI      X          X          X                                           X
#            PCE_Prices      X          X          X                                           X
# Industrial_Production      X          X          X            X
#       Personal_Income      X          X          X                                                                               X
#     Disposable_Income      X          X          X                                                                               X
#  Capacity_Utilization      X          X          X            X
#                   PCE      X          X          X            X
#          Retail_Sales      X          X          X            X
#            New_Orders      X          X          X            X
#    Michigan_Sentiment      X          X          X
#          Unemployment      X          X          X                                                      X
#                   NFP      X          X          X                                                      X
#        Initial_Claims      X          X          X                                                      X
#               Permits      X          X          X                                                                    X
#        Housing_Starts      X          X          X                                                                    X
#        Mortgage_Rates      X          X          X                          X
#             10y_Yield      X          X          X                          X
#              2y_Yield      X          X          X                          X
#             Fed_Funds      X          X          X                          X
#                   VIX      X          X          X                          X
#          Money_Supply      X          X          X                          X
#                Stocks      X          X          X                          X
#                   DXY      X          X          X                          X
#                   GDP      X          X          X            X
#               GDP_PCE      X          X          X            X
#                  GPDI      X          X          X            X
#                   GCE      X          X          X                          X
#               Imports      X          X          X            X
#               Exports      X          X          X            X
#          GDP_deflator      X          X          X                                           X
#              Factor blocks:
# =======================================
#                        block      order
# ---------------------------------------
# Global.1, Global.2, Global.3          3
#                       Demand          3
#         Financial_Conditions          3
#                    Inflation          3
#                 Labor Market          3
#                      Housing          3
#                       Income          3
# =======================================
# """

# %%
results = model.fit(maxiter=1000000, disp=100)

print(results.summary())
# Out:
# EM start iterations, llf=-5923
# EM iteration 100, llf=-5156.2, convergence criterion=5.5025e-06
# EM iteration 200, llf=-5154.6, convergence criterion=2.4349e-06
# KeyboardInterrupt

# %%
results.save('gdp_model.pkl')

# %%
if cutoff > 1:
    results_appended = results.append(endog = data[-cutoff:-1])
else:
    results_appended = results

# Specify the number of steps ahead you want to forecast
steps_ahead = 3  # For example, forecasting 12 months ahead
const_forecast = np.ones(steps_ahead)
# Generate forecasts
forecasts = results_appended.forecast(steps=steps_ahead, exog=const_forecast)

# The 'forecasts' variable now contains the forecasted values for each variable for the next 12 months
print(forecasts)
# Out:
#          Crude_Oil       PPI       CPI  PCE_Prices  Industrial_Production  \
# 2024-04   2.663821  0.635447  0.397405    0.315193               0.211965
# 2024-05   1.002730  0.381319  0.283840    0.235688               0.147065
# 2024-06   0.201697  0.340479  0.268483    0.223411               0.040269
#
#          Personal_Income  Disposable_Income  Capacity_Utilization       PCE  \
# 2024-04        -0.017328          -0.100024              7.203970  0.293071
# 2024-05         0.479197           0.477166              3.493633  0.244190
# 2024-06         0.266750           0.244686             -4.084981  0.133657
#
#          Retail_Sales  ...  Money_Supply    Stocks       DXY       GDP  \
# 2024-04      0.310762  ...      0.374984  1.120500 -0.395378  0.706218
# 2024-05      0.265304  ...      0.471291  0.819583 -0.045188  0.862324
# 2024-06      0.069118  ...      0.487216  0.327295  0.119205  0.959240
#
#           GDP_PCE      GPDI       GCE   Imports   Exports  GDP_deflator
# 2024-04  0.850515  1.337526  0.154054  2.427346  1.019656      0.883446
# 2024-05  0.987093  1.891987  0.102367  2.677701  1.572540      0.883834
# 2024-06  1.019859  1.588320  0.117756  2.394209  1.833584      0.815175
#
# [3 rows x 32 columns]

# %%
results_appended.get_prediction(start='2024-03-31', end='2024-06-30').summary_frame(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\envs\transports\lib\site-packages\statsmodels\tsa\base\tsa_model.py:249, in get_index_label_loc(key, index, row_labels)
#     248 if not isinstance(key, (int, np.integer)):
# --> 249     loc = row_labels.get_loc(key)
#     250 else:
#
# File ~\AppData\Local\anaconda3\envs\transports\lib\site-packages\pandas\core\indexes\period.py:425, in PeriodIndex.get_loc(self, key)
#     424     else:
# --> 425         raise KeyError(key)
#     427 elif isinstance(key, Period):
#
# KeyError: '2024-03-31'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\envs\transports\lib\site-packages\statsmodels\tsa\base\tsa_model.py:358, in get_prediction_index(start, end, nobs, base_index, index, silent, index_none, index_generated, data)
#     357 try:
# --> 358     start, _, start_oos = get_index_label_loc(
#     359         start, base_index, data.row_labels
#     360     )
#     361 except KeyError:
#
# File ~\AppData\Local\anaconda3\envs\transports\lib\site-packages\statsmodels\tsa\base\tsa_model.py:281, in get_index_label_loc(key, index, row_labels)
#     280     except:
# --> 281         raise e
#     282 return loc, index, index_was_expanded
#
# File ~\AppData\Local\anaconda3\envs\transports\lib\site-packages\statsmodels\tsa\base\tsa_model.py:245, in get_index_label_loc(key, index, row_labels)
#     244 try:
# --> 245     loc, index, index_was_expanded = get_index_loc(key, index)
#     246 except KeyError as e:
#
# File ~\AppData\Local\anaconda3\envs\transports\lib\site-packages\statsmodels\tsa\base\tsa_model.py:178, in get_index_loc(key, index)
#     176 if date_index:
#     177     # (note that get_loc will throw a KeyError if key is invalid)
# --> 178     loc = index.get_loc(key)
#     179 elif int_index or range_index:
#     180     # For NumericIndex and RangeIndex, key is assumed to be the location
#     181     # and not an index value (this assumption is required to support
#     182     # RangeIndex)
#
# File ~\AppData\Local\anaconda3\envs\transports\lib\site-packages\pandas\core\indexes\period.py:425, in PeriodIndex.get_loc(self, key)
#     424     else:
# --> 425         raise KeyError(key)
#     427 elif isinstance(key, Period):
#
# KeyError: '2024-03-31'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[353], line 1
# ----> 1 results_appended.get_prediction(start='2024-03-31', end='2024-06-30').summary_frame(5)
#
# File ~\AppData\Local\anaconda3\envs\transports\lib\site-packages\statsmodels\tsa\statespace\dynamic_factor_mq.py:3642, in DynamicFactorMQResults.get_prediction(self, start, end, dynamic, information_set, signal_only, original_scale, index, exog, extend_model, extend_kwargs, **kwargs)
#    3584 r"""
#    3585 In-sample prediction and out-of-sample forecasting.
#    3586
#    (...)
#    3639     forecasts. An (npredict x k_endog) array.
#    3640 """
#    3641 # Get usual predictions (in the possibly-standardized scale)
# -> 3642 res = super().get_prediction(start=start, end=end, dynamic=dynamic,
#    3643                              information_set=information_set,
#    3644                              signal_only=signal_only,
#    3645                              index=index, exog=exog,
#    3646                              extend_model=extend_model,
#    3647                              extend_kwargs=extend_kwargs, **kwargs)
#    3649 # If applicable, convert predictions back to original space
#    3650 if self.model.standardize and original_scale:
#
# File ~\AppData\Local\anaconda3\envs\transports\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py:3340, in MLEResults.get_prediction(self, start, end, dynamic, information_set, signal_only, index, exog, extend_model, extend_kwargs, **kwargs)
#    3336     start = 0
#    3338 # Handle start, end, dynamic
#    3339 start, end, out_of_sample, prediction_index = (
# -> 3340     self.model._get_prediction_index(start, end, index))
#    3342 # Handle `dynamic`
#    3343 if isinstance(dynamic, (str, dt.datetime, pd.Timestamp)):
#
# File ~\AppData\Local\anaconda3\envs\transports\lib\site-packages\statsmodels\tsa\base\tsa_model.py:836, in TimeSeriesModel._get_prediction_index(self, start, end, index, silent)
#     780 """
#     781 Get the location of a specific key in an index or model row labels
#     782
#    (...)
#     833 since we have required them to be full indexes, there is no ambiguity).
#     834 """
#     835 nobs = len(self.endog)
# --> 836 return get_prediction_index(
#     837     start,
#     838     end,
#     839     nobs,
#     840     base_index=self._index,
#     841     index=index,
#     842     silent=silent,
#     843     index_none=self._index_none,
#     844     index_generated=self._index_generated,
#     845     data=self.data,
#     846 )
#
# File ~\AppData\Local\anaconda3\envs\transports\lib\site-packages\statsmodels\tsa\base\tsa_model.py:362, in get_prediction_index(start, end, nobs, base_index, index, silent, index_none, index_generated, data)
#     358     start, _, start_oos = get_index_label_loc(
#     359         start, base_index, data.row_labels
#     360     )
#     361 except KeyError:
# --> 362     raise KeyError(
#     363         "The `start` argument could not be matched to a"
#     364         " location related to the index of the data."
#     365     )
#     366 if end is None:
#     367     end = max(start, len(base_index) - 1)
#
# KeyError: 'The `start` argument could not be matched to a location related to the index of the data.'

# %% [markdown]
# ## Update Existing Forecasts

# %%
#start_date = str(data.index[-1])[:7]
#end_date = str(data.index[-1] + timedelta(32))[:7]
def get_news(data, data_quarterly, results, lookback=1):
    start_date = data.index[-lookback]
    #print(start_date)
    end_date = start_date + relativedelta(months=lookback+1)
    end_date = datetime(end_date.year, end_date.month, 1) - timedelta(days=1)
    #print(results.summary())

    #const_post_plus1 = np.ones(len(data) + 1)
    news = results.news(data, endog_quarterly = data_quarterly, start=start_date, end=end_date, freq ='M')
    return news

news = get_news(data, data_quarterly, results_appended)

print(news.summary())
# Out:
#                                       News
# ===============================================================================
# Model:                DynamicFactorMQ   Original sample:                2003-04
# Date:                Thu, 09 May 2024                                 - 2024-03
# Time:                        11:58:30   Update through:                 2024-04
#                                         # of revisions:                       0
#                                         # of new datapoints:                 10
#                                     Impacts
# ===============================================================================
# impact date     impacted variable estimate (prev) impact of news estimate (new)
# -------------------------------------------------------------------------------
#     2024-04             10y_Yield           -1.14          34.14          33.00
#         NaT              2y_Yield            1.02          26.98          28.00
#         NaT                   CPI            0.40           0.08           0.48
#         NaT  Capacity_Utilization            7.20         -18.58         -11.38
#         NaT             Crude_Oil            2.66           2.22           4.89
#         NaT                   DXY           -0.40           1.60           1.21
#         NaT     Disposable_Income           -0.10           0.13           0.03
#         NaT               Exports            1.02          -0.10           0.92
#         NaT             Fed_Funds            0.76          -0.76           0.00
#         NaT                   GCE            0.15           0.02           0.17
#         NaT                   GDP            0.71          -0.05           0.65
#         NaT               GDP_PCE            0.85          -0.07           0.78
#         NaT          GDP_deflator            0.88           0.01           0.89
#         NaT                  GPDI            1.34          -0.11           1.23
#         NaT        Housing_Starts            7.66          -0.42           7.24
#         NaT               Imports            2.43          -0.13           2.30
#         NaT Industrial_Production            0.21          -0.27          -0.05
#         NaT        Initial_Claims           -1.32           0.18          -1.14
#         NaT    Michigan_Sentiment           -0.22          -0.49          -0.71
#         NaT          Money_Supply            0.37          -0.02           0.35
#         NaT        Mortgage_Rates           -1.25          18.25          17.00
#         NaT                   NFP            0.32          -0.21           0.11
#         NaT            New_Orders            0.44           0.01           0.45
#         NaT                   PCE            0.29          -0.24           0.06
#         NaT            PCE_Prices            0.32           0.06           0.38
#         NaT                   PPI            0.64           0.30           0.93
#         NaT               Permits            1.36          -0.13           1.24
#         NaT       Personal_Income           -0.02           0.11           0.09
#         NaT          Retail_Sales            0.31          -0.29           0.02
#         NaT                Stocks            1.12          -1.61          -0.49
#         NaT          Unemployment          -18.25          28.25          10.00
#         NaT                   VIX           -1.54          17.28          15.74
#     2024-05             10y_Yield            1.40           9.95          11.35
#         NaT              2y_Yield            2.55          10.62          13.18
#         NaT                   CPI            0.28           0.04           0.32
#         NaT  Capacity_Utilization            3.49          10.91          14.40
#         NaT             Crude_Oil            1.00           1.99           2.99
#         NaT                   DXY           -0.05           0.36           0.32
#         NaT     Disposable_Income            0.48           0.05           0.52
#         NaT               Exports            1.57          -0.14           1.44
#         NaT             Fed_Funds            0.55           0.29           0.84
#         NaT                   GCE            0.10           0.03           0.13
#         NaT                   GDP            0.86          -0.07           0.79
#         NaT               GDP_PCE            0.99          -0.09           0.90
#         NaT          GDP_deflator            0.88           0.02           0.91
#         NaT                  GPDI            1.89          -0.15           1.74
#         NaT        Housing_Starts           -3.53           0.88          -2.66
#         NaT               Imports            2.68          -0.19           2.49
#         NaT Industrial_Production            0.15           0.15           0.29
#         NaT        Initial_Claims            0.02          -1.86          -1.85
#         NaT    Michigan_Sentiment            0.14           0.30           0.44
#         NaT          Money_Supply            0.47          -0.05           0.42
#         NaT        Mortgage_Rates            1.20           8.32           9.52
#         NaT                   NFP            0.13           0.09           0.23
#         NaT            New_Orders            0.54           0.38           0.92
#         NaT                   PCE            0.24           0.16           0.40
#         NaT            PCE_Prices            0.24           0.03           0.26
#         NaT                   PPI            0.38           0.18           0.56
#         NaT               Permits            0.03           0.59           0.62
#         NaT       Personal_Income            0.48           0.05           0.53
#         NaT          Retail_Sales            0.27           0.30           0.56
#         NaT                Stocks            0.82          -0.04           0.78
#         NaT          Unemployment           -4.79          -7.72         -12.52
#         NaT                   VIX           -0.97          -2.07          -3.04
#                   News from updated observations:
# ===================================================================
# update date updated variable   observed forecast (prev)        news
# -------------------------------------------------------------------
#     2024-04        10y_Yield      33.00           -1.14       34.14
#                     2y_Yield      28.00            1.02       26.98
#                    Crude_Oil       4.89            2.66        2.22
#                          DXY       1.21           -0.40        1.60
#                    Fed_Funds       0.00            0.76       -0.76
#               Initial_Claims      -1.14           -1.32        0.18
#               Mortgage_Rates      17.00           -1.25       18.25
#                          NFP       0.11            0.32       -0.21
#                 Unemployment      10.00          -18.25       28.25
#                          VIX      15.74           -1.54       17.28
# ===================================================================

# %%
new_forecasts.index.to_timestamp('M')
# Out:
# DatetimeIndex(['2024-04-30', '2024-05-31', '2024-06-30'], dtype='datetime64[ns]', freq='M')

# %%
def update_forecast_data(forecast_df, news,length=3):
    if length < 3:
        length = 3
    
    new_df = forecast_df.copy()
    num_cols = len(new_df.columns)
    for i in range(1,length):
        for j in range(num_cols):
            revision_date = news.impacts.index[j*i][0]
            col_name = news.impacts.index[j*i][1]
            new_df.loc[revision_date, col_name] = news.impacts.iloc[j*i,4]
    return new_df

def combine_data(history_df, forecast_df):
    #print(data)
    num_cols = len(history_df.columns)
    if num_cols == len(forecast_df.columns):
        new_df = pd.concat([history_df, forecast_df])
        #for i in range(num_cols):
        #    if np.isnan(history_df.iloc[-1,i]):
        #        new_df.iloc[-len(forecast_df),i] = forecast_df.iloc[0,i]
        return new_df
    else:
        raise ValueError()

new_forecasts = update_forecast_data(forecasts, news)
new_forecasts.index = new_forecasts.index.to_timestamp('M')
new_forecasts_quarterly = new_forecasts[data_quarterly.columns].resample('Q').last()
new_data = combine_data(data_quarterly, new_forecasts_quarterly)
new_data.tail(5)
# Out:
#                  GDP   GDP_PCE      GPDI       GCE   Imports   Exports  \
# 2023-06-30  0.509820  0.200304  1.264324  0.821831 -1.973408 -2.434315
# 2023-09-30  1.186801  0.765005  2.386081  1.403613  1.028948  1.314463
# 2023-12-31  0.834910  0.807076  0.185158  1.129171  0.547514  1.232444
# 2024-03-31  0.394345  0.619352  0.781656  0.294549  1.736817  0.226383
# 2024-06-30  0.959240  1.019859  1.588320  0.117756  2.394209  1.833584
#
#             GDP_deflator
# 2023-06-30      0.415592
# 2023-09-30      0.814635
# 2023-12-31      0.413766
# 2024-03-31      0.770120
# 2024-06-30      0.815175

# %%
data.resample('Q').last()
# Out:
#          Crude_Oil       PPI       CPI  PCE_Prices  Industrial_Production  \
# 2024-04   4.886047  0.933761  0.480826    0.375754              -0.054945
# 2024-05   2.989815  0.381319  0.321234    0.263771               0.294335
# 2024-06   0.201697  0.340479  0.268483    0.223411               0.040269
#
#          Personal_Income  Disposable_Income  Capacity_Utilization       PCE  \
# 2024-04         0.087756           0.029798            -11.379169  0.055632
# 2024-05         0.479197           0.522509              3.493633  0.244190
# 2024-06         0.266750           0.244686             -4.084981  0.133657
#
#          Retail_Sales  ...  Money_Supply    Stocks       DXY       GDP  \
# 2024-04      0.022083  ...      0.351212 -0.491935  1.209513  0.651433
# 2024-05      0.563176  ...      0.471291  0.819583 -0.045188  0.793666
# 2024-06      0.069118  ...      0.487216  0.327295  0.119205  0.959240
#
#           GDP_PCE      GPDI       GCE   Imports   Exports  GDP_deflator
# 2024-04  0.783792  1.226118  0.170003  2.300822  0.916290      0.893672
# 2024-05  0.987093  1.891987  0.102367  2.677701  1.572540      0.906930
# 2024-06  1.019859  1.588320  0.117756  2.394209  1.833584      0.815175
#
# [3 rows x 32 columns]

# %%
new_forecasts[data_quarterly.columns]*4
# Out:
#               GDP   GDP_PCE      GPDI       GCE    Imports   Exports  \
# 2024-04  2.605733  3.135167  4.904473  0.680011   9.203287  3.665158
# 2024-05  3.174663  3.948371  7.567949  0.409469  10.710802  6.290161
# 2024-06  3.836961  4.079437  6.353282  0.471023   9.576835  7.334337
#
#          GDP_deflator
# 2024-04      3.574689
# 2024-05      3.627719
# 2024-06      3.260701

# %%
data_quarterly*4
# Out:
#                  GDP   GDP_PCE       GPDI       GCE    Imports    Exports  \
# date
# 2003-06-30  3.526892  4.553907   2.590895  3.652737   5.788782   0.703577
# 2003-09-30  6.598081  5.616338  14.205957  0.906129   6.215738  10.781382
# 2003-12-31  4.616147  2.744373  13.421117  2.405895  12.507207  17.591722
# 2004-03-31  2.260208  3.712200   0.674991  1.805212  11.049261   8.945797
# 2004-06-30  3.087860  2.176651  15.602274  1.066437  15.454865   8.297510
# ...              ...       ...        ...       ...        ...        ...
# 2023-03-31  2.219354  3.712345  -9.454429  4.706561   1.257291   6.603664
# 2023-06-30  2.039281  0.801216   5.057295  3.287324  -7.893631  -9.737258
# 2023-09-30  4.747202  3.060018   9.544322  5.614452   4.115792   5.257851
# 2023-12-31  3.339638  3.228304   0.740632  4.516685   2.190057   4.929775
# 2024-03-31  1.577379  2.477410   3.126624  1.178197   6.947267   0.905531
#
#             GDP_deflator
# date
# 2003-06-30      1.404784
# 2003-09-30      2.282022
# 2003-12-31      2.428823
# 2004-03-31      2.844100
# 2004-06-30      3.214956
# ...                  ...
# 2023-03-31      3.871522
# 2023-06-30      1.662369
# 2023-09-30      3.258541
# 2023-12-31      1.655065
# 2024-03-31      3.080481
#
# [84 rows x 7 columns]

# %%
len(data)/3
# Out:
# 84

# %%
len(data_quarterly)
# Out:
# 84

# %% [markdown]
# ## Recursive Estimation

# %%
def recursive_estimation(data, data_quarterly, factors = 1, factor_orders = 3, factor_multiplicities = 1, steps_ahead = 2, start_point = 50, missing_var_names = None):
    if missing_var_names is None:
        missing_var_names = list(data.columns[data.iloc[-1].isna()])

    errors_df = pd.DataFrame(0, index=range(steps_ahead), columns=data.columns)
    preds_dfs = [pd.DataFrame(columns=data.columns)]*steps_ahead
    for i in range(start_point, len(data_quarterly)-steps_ahead+1):
        print(len(data) - i)
        model = sm.tsa.DynamicFactorMQ(data[:i], endog_quarterly = data_quarterly[:math.floor(i/3)], factors=factors, factor_orders=factor_orders, factor_multiplicities = factor_multiplicities)#,enforce_stationarity=False)
        results = model.fit(maxiter=100000, disp=100)

        # Generate forecasts
        forecasts = results.forecast(steps=steps_ahead)

        if len(missing_var_names) > 0:
            new_data = data.copy()[:i+1]
            for j, col in enumerate(new_data.columns):
                if col in missing_var_names:
                    new_data.iloc[-1, j] = np.nan
                    #print(new_data.tail())

            news = get_news(new_data, data_quarterly[:math.floor(i/3)], results)
            #print(news.impacts)
            forecasts = update_forecast_data(forecasts, news)
            forecasts.index = forecasts.index.to_timestamp('M')
            forecasts = forecasts[data_quarterly.columns].resample('Q').last()
            forecasts = forecasts[:steps_ahead]
            #print(forecasts)
            
        # Compare Observed Values with Forecast and Record Results
        observed = data.copy()[i:i+steps_ahead]
        has_nans = observed.isna().any().any()
        if not has_nans:
            error = (forecasts - observed).reset_index(drop = True)
            errors_df = errors_df + error**2
        #display(errors_df)
        
        for k in range(steps_ahead):
            preds_dfs[k] = pd.concat([preds_dfs[k], forecasts[k:k+1]])

    errors_df = (errors_df / (len(data) - start_point - steps_ahead + 1))**0.5
        
    return preds_dfs, errors_df

# %%
cutoff=3
start_point = len(data[:-1]) - cutoff
missing_vars = list(data.columns[data.iloc[-1].isna()])
#missing_vars.remove('PPI')
preds_dfs, errors_df = recursive_estimation(data,
                                            data_quarterly,
                                 factors = factors,
                                 factor_orders = 3,
                                 factor_multiplicities = factor_multiplicities,
                                 steps_ahead = 1,
                                 start_point = start_point,
                                 missing_var_names = missing_vars)
# Out:
# 3
# EM start iterations, llf=-5840.6
# KeyboardInterrupt

# %% [markdown]
# ## Comparison

# %%
cutoff = 150
var_name = 'Core PCE'

# %% [markdown]
# #### Nowcasting Model

# %%
plt.plot(preds_dfs[0].index[-cutoff:], preds_dfs[0][var_name][-cutoff:], label='Predicted')
plt.plot(data.index[-cutoff:], data[var_name][-cutoff:], label=var_name, linestyle='--')
plt.legend()
plt.show()

# %%
errors_df[missing_vars]

# %%
def get_r_squared(var_name, pred_df, actual_df):
    r2 = np.round(np.corrcoef(pred_df[var_name], actual_df[var_name])[1][0]**2*100, 1)
    return r2

mse = errors_df[var_name][0]
r2 = get_r_squared(var_name, preds_dfs[0], data[start_point:-1])

print(f"Root Mean Squared Error: {mse}")
print(f"R-Squared : {r2}")

# %% [markdown]
# #### Naive Forecast

# %%
mse = ((((data[-cutoff:-1] - data[-cutoff:-1].shift(1)).dropna()**2).mean())**0.5)[var_name]
r2 = get_r_squared(var_name, data[-cutoff:-1].shift(1).dropna(), data[-cutoff+1:-1])

print(f"Root Mean Squared Error: {mse}")
print(f"R-Squared : {r2}")

# %% [markdown]
# #### AR(1) Model

# %%
from statsmodels.regression.linear_model import OLS
from statsmodels.tools.tools import add_constant

def fit_ar1_initial_slice(data, initial_slice):
    """
    Fit AR(1) model to the initial slice of the data.
    
    Parameters:
    data (array-like): The dataset.
    initial_slice (int): The end index of the initial slice of data to fit the model on.
    
    Returns:
    tuple: Fitted values of c (intercept) and phi (coefficient).
    """
    # Prepare the lagged version of the series
    X = data[:initial_slice-1]
    Y = data[1:initial_slice]
    X = add_constant(X)  # Add intercept term
    
    # Fit the model
    model = OLS(Y, X).fit()
    
    return model.params[0], model.params[1]  # Intercept (c) and coefficient (phi)

def predict_ar1(c, phi, X_prev):
    """
    Predict the next value in an AR(1) process.
    
    Parameters:
    c (float): Intercept term from AR(1) model.
    phi (float): Coefficient from AR(1) model.
    X_prev (float): The previous observed value in the series.
    
    Returns:
    float: Predicted next value of the series.
    """
    return c + phi * X_prev

def evaluate_recursive_ar1(data, initial_slice):
    """
    Evaluate the predictive performance of a recursive AR(1) on a dataset.
    
    Parameters:
    data (array-like): The dataset to be used.
    initial_slice (int): The end index of the initial slice of data to fit the model on.
    
    Returns:
    float: Mean Squared Error of the predictions.
    """
    # Fit the AR(1) model on the initial slice
    c, phi = fit_ar1_initial_slice(data, initial_slice)
    
    # Initialize list to store predictions
    predictions = []
    
    # Predict and update step
    for t in range(initial_slice, len(data)):
        X_prev = data[t-1]
        pred = predict_ar1(c, phi, X_prev)
        predictions.append(pred)
    
    # Calculate Mean Squared Error
    mse = np.mean((data[initial_slice:] - predictions)**2)**0.5
    r2 = np.corrcoef(data[initial_slice:], predictions)**2
    return predictions, mse, r2

predictions, mse, r2 = evaluate_recursive_ar1(np.array(data[:-1][var_name]), cutoff)
print(f"Root Mean Squared Error: {mse}")
print(f"R-Squared : {np.round(r2[1][0]*100,1)}")

# %% [markdown]
# #### Cleveland Fed

# %%
file_path = Path("cleveland_fed_nowcast.xlsx")
cleveland_df = pd.read_excel(file_path).set_index('date').dropna().drop_duplicates().reset_index()
cleveland_df = cleveland_df[cleveland_df['date'] < '2024-02-01']

cleveland_df = cleveland_df[cleveland_df['date'].dt.day < 10]

cleveland_df['prev_date'] = cleveland_df['date'].shift(-1)

# Keep only the rows where the month of the date is different from the month of the next date
# Or if it's the last row, as the shift would introduce a NaT (not a time) value
cleveland_df = cleveland_df[(cleveland_df['date'].dt.month != cleveland_df['prev_date'].dt.month) | (cleveland_df['prev_date'].isna())]

cleveland_df['date'] = cleveland_df['date'] + pd.offsets.MonthEnd()
cleveland_df = cleveland_df.drop(columns='prev_date').set_index('date')

cleveland_df = cleveland_df[cleveland_df[var_name] < 1]

# %%
cleveland_cutoff = len(cleveland_df)
mse = ((((cleveland_df - data[['CPI', 'Core CPI', 'PCE', 'Core PCE']][data.index >= cleveland_df.index[0]])**2).mean())**0.5)[var_name]
r2 = get_r_squared(var_name, cleveland_df, data[data.index.isin(cleveland_df.index)])


print(f"Root Mean Squared Error: {mse}")
print(f"R-Squared : {r2}")

# %%
plt.plot(cleveland_df.index, cleveland_df[var_name], label='Predicted')
plt.plot(data.index[-cleveland_cutoff:], data[var_name][-cleveland_cutoff:], label=var_name, linestyle='--')
plt.legend()
plt.show()

# %%
## Post CPI Release
cleveland_df = pd.read_excel(file_path).set_index('date').dropna().drop_duplicates().reset_index()
cleveland_df = cleveland_df[cleveland_df['date'] < '2024-02-01']

cleveland_df = cleveland_df[cleveland_df['date'].dt.day > 20]

cleveland_df = cleveland_df[cleveland_df['date'].dt.dayofweek.isin([3, 4, 5])]

cleveland_df['prev_date'] = cleveland_df['date'].shift(-1)

# Keep only the rows where the month of the date is different from the month of the next date
# Or if it's the last row, as the shift would introduce a NaT (not a time) value
cleveland_df = cleveland_df[(cleveland_df['date'].dt.month != cleveland_df['prev_date'].dt.month) | (cleveland_df['prev_date'].isna())]

cleveland_df['date'] = cleveland_df['date'] -timedelta(days=1) + pd.offsets.MonthEnd()

cleveland_df = cleveland_df.drop(columns='prev_date').set_index('date')

# %%
cleveland_df = cleveland_df[cleveland_df[var_name] < 1]

# %%
cleveland_cutoff = len(cleveland_df)
mse = ((((cleveland_df - data[['CPI', 'Core CPI', 'PCE', 'Core PCE']][data.index >= cleveland_df.index[0]])**2).mean())**0.5)[var_name]
r2 = get_r_squared(var_name, cleveland_df, data[data.index.isin(cleveland_df.index)])

print(f"Root Mean Squared Error: {mse}")
print(f"R-Squared : {r2}")

# %%
plt.plot(cleveland_df.index, cleveland_df[var_name], label='Predicted')
plt.plot(data.index[-cleveland_cutoff:], data[var_name][-cleveland_cutoff:], label=var_name, linestyle='--')
plt.legend()
plt.show()

# %%
## VS Model Forecasts for Same Time Window

mse = ((((preds_dfs[0][['CPI', 'Core CPI', 'PCE', 'Core PCE']][-cleveland_cutoff:] - data[['CPI', 'Core CPI', 'PCE', 'Core PCE']][-cleveland_cutoff:-1]).dropna()**2).mean())**0.5)[var_name]
r2 = get_r_squared(var_name, preds_dfs[0], data[start_point:-1])

print(f"Root Mean Squared Error: {mse}")
print(f"R-Squared : {r2}")
